# %%
import pandas as pd

# %%
class TempoExam:
    def __init__(self,hours,minuts,seconds):
        self.hours = hours
        self.minuts = minuts
        self.seconds = seconds

    def to_seconds(self):
        return self.hours*3600  + self.minuts * 60 + self.seconds

# %%
exame_df_pnes_pc2 = pd.read_excel('Patient2-inducao.xlsx')
# Out:
# 119200

# %%
exame_df_pnes_pc2[::200].reset_index(drop=True)
# Out:
#       time      Fp1-F3      F3-C3      C3-P3      P3-O1      Fp1-F7  \
# 0      0.0  249.902360  62.988039  47.851979  20.312325  319.140541
# 1      1.0  137.011757  38.378665  37.793392  15.136546  185.058535
# 2      2.0   91.796922  23.925545  35.449642   5.370927  112.011671
# 3      3.0   53.222711  13.769295  38.281672   0.976398   50.292931
# 4      4.0   30.273497   2.929455  17.871527 -10.254064   28.710905
# ..     ...         ...        ...        ...        ...         ...
# 591  591.0  -76.855389  -5.761947   6.641063 -30.468896  -82.519543
# 592  592.0  -64.062423  10.937260   5.957473 -35.742331  -29.101580
# 593  593.0  -60.156172 -15.820551   1.855914 -43.652483  -39.746107
# 594  594.0  -47.363206  -9.472890   9.473095 -26.757961  -30.273455
# 595  595.0  -15.234306   6.054439  13.672316   2.538897   17.285133
#
#          F7-T3      T3-T5      T5-O1      Fp2-F4      F4-C4      C4-P4  \
# 0    23.339683  50.000162 -11.425682  254.397917  84.863170  31.542816
# ...

# %%
intervalo_analise_pc2_inicio
# Out:
# 530

# %%
intervalo_analise_pc2_inicio

# %%
exame_df_pnes_pc2_inicio = Tempo(10,11,10)
exame_df_pnes_pc2_final = Tempo(10,21,6)
duracao_exame_pc2 = exame_df_pnes_pc2_final.to_seconds() - exame_df_pnes_pc2_inicio.to_seconds()
intervalo_analise_pc2_inicio = Tempo(10,14,16).to_seconds() - exame_df_pnes_pc2_inicio.to_seconds()
intervalo_analise_pc2_final=Tempo(10,16,20).to_seconds() - exame_df_pnes_pc2_inicio.to_seconds()

# %%
exame_df_pnes_pc2_inicio = Tempo(10,11,10)
exame_df_pnes_pc2_final = Tempo(10,21,6)
exame_df_pnes_pc2_final.to_seconds() - exame_df_pnes_pc2_inicio.to_seconds()
intervalo_analise_pc2_inicio = Tempo(10,20,00).to_seconds() - exame_df_pnes_pc2_inicio.to_seconds()
intervalo_analise_pc2_final = Tempo(10,20,54).to_seconds() - exame_df_pnes_pc2_inicio.to_seconds()

# %%
exame_df_es_pc16 = pd.read_excel('Patient16-crise_desencadeada.xlsx')

# %%
exame_df_es_pc16
# Out:
#           time     Fp1-F3      F3-C3      C3-P3       P3-O1      Fp1-F7  \
# 0        0.000  11.230114  -6.640295  12.694705   23.438083  -35.449186
# 1        0.005  14.550419  -5.175445   8.202518   33.008394  -41.699186
# 2        0.010   9.472300   0.488612  11.425172   27.539647  -30.468718
# 3        0.015  12.304309  -5.468398  10.741577   18.848243  -33.007780
# 4        0.020  12.792608  -0.780916  10.546266    9.570899  -42.773404
# ...        ...        ...        ...        ...         ...         ...
# 52795  263.975 -46.875267  36.426025  58.397807  112.891216 -103.808554
# 52796  263.980 -35.254167  43.261953  70.702488   86.426381  -90.527306
# 52797  263.985 -56.347917  44.238519  62.499366   92.969347 -117.871053
# 52798  263.990 -53.222923  38.672119  53.222028   80.469344 -112.206991
# 52799  263.995 -45.703375  51.953349  67.382176  128.320908  -89.453087
#
#             F7-T3      T3-T5       T5-O1      Fp2-F4       F4-C4      C4-P4  \
# ...

# %%
tempo_exam_pc16_inicio = Tempo(17,42,17)
tempo_exam_pc16_final = Tempo(17,46,41)
duracao_exame_pc16 = tempo_exam_pc16_final.to_seconds() - tempo_exam_pc16_inicio.to_seconds()
intervalo_analise_pc16_inicio = Tempo(17,43,23).to_seconds() - tempo_exam_pc16_inicio.to_seconds()
intervalo_analise_pc16_final = Tempo(17,44,33).to_seconds() - tempo_exam_pc16_inicio.to_seconds()

# %%
duracao_exame_pc2,duracao_exame_pc16
# Out:
# (596, 264)

# %%
intervalo_analise_pc2_final
# Out:
# 584

# %%
intervalo_analise_pc2_inicio
# Out:
# 530

# %%
exame_df_pnes_pc2[intervalo_analise_pc2_inicio:intervalo_analise_pc2_final].plot()
exame_df_es_pc16[intervalo_analise_pc16_inicio:intervalo_analise_pc16_final].plot()
# Out:
# <AxesSubplot: >

# %%
patient_event = exame_df_pnes_pc2
patient_event.index = patient_event.time
patient_event = patient_event.drop(['time'], axis=1)

amostragem = len(patient_event)/200
comprimento_sinal = int(amostragem)
discrete_patient_event = patient_event.iloc[::comprimento_sinal, :]
discrete_patient_event.plot()
# Out:
# <AxesSubplot: xlabel='time'>

# %%
exame_df_pnes_pc2[::200].plot()
exame_df_es_pc16[::200].plot()
# Out:
# <AxesSubplot: >
