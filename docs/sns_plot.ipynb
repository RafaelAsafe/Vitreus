# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("dataset_not_normalized.xlsx")
df=df.drop(columns=['cod_exame','Unnamed: 0'])
df
# Out:
#     id_paciente    mediaA5       mediaD5   mediaD4   mediaD3   mediaD2  \
# 0             1   5.315671  3.410605e-16  0.129469 -0.347532 -0.138354
# 1             1   2.007625  1.421085e-15 -0.190576 -0.212867  0.300267
# 2             1   2.983112  5.666578e-16 -0.493331  1.819035  2.425766
# 3             1  -6.851432  5.115908e-16  0.216638  0.221833  0.976413
# 4             1   5.212388  1.776357e-16  0.194761 -0.467803 -0.538200
# ..          ...        ...           ...       ...       ...       ...
# 139          30   2.074674  4.778400e-16  0.185850 -0.078706  0.629065
# 140          30   1.355568  4.263256e-17  0.098359 -0.347973  0.669726
# 141          30   8.329793  1.392664e-15  0.037496 -0.157905 -0.165509
# 142          30   6.019530  5.755396e-16 -0.016369 -0.028153 -0.728769
# 143          30 -13.643900 -8.242296e-16  0.252090  0.494681  2.392665
#
#       mediaD1   desvpadA5   desvpadD5  desvpadD4  ...    maximoD3  \
# 0    0.020343  267.292010   54.035904  51.384376  ...  264.022379
# 1    0.356130  382.281372  106.250497  80.587315  ...  620.878504
# 2    5.690645  282.539471   51.501965  42.432100  ...  719.010709
# 3    0.754556  521.724986  102.292031  72.427367  ...  677.523138
# 4   -0.530409  332.543045   60.469314  60.941389  ...  459.167917
# ..        ...         ...         ...        ...  ...         ...
# 139 -0.061252  326.997894   86.221645  84.761939  ...  977.543460
# 140 -0.036275  195.364917   32.723750  36.864655  ...  287.007359
# 141 -0.095693  324.063462   88.733044  71.148243  ...  688.194181
# 142 -0.043738   96.795497   15.847624  14.771371  ...   82.319054
# 143 -0.520641  189.049332   41.966223  41.552847  ...  529.292689
#
#         maximoD2     maximoD1     minimoA5     minimoD5     minimoD4  \
# 0     473.633649   755.779771 -1349.790674  -330.645291  -307.386614
# 1     853.979235  1331.911757 -2812.493956 -1419.836043 -1233.713319
# 2    2091.818478  4755.177246 -2703.185362  -323.710399  -380.683898
# 3     986.070596   953.713672 -3049.005651  -633.169553  -740.436980
# 4    1061.781250  1447.558175 -2866.387714  -546.025371  -606.501912
# ..           ...          ...          ...          ...          ...
# 139  1567.332659  2499.120218 -2096.459920  -667.726271 -1101.181404
# 140   478.704308   820.025622  -949.318303  -182.054040  -343.268327
# 141   315.704817   542.570520 -2117.003102  -686.628284  -453.136060
# 142   145.069307   193.334327  -429.500030  -119.986158   -84.784760
# 143   426.080512   825.408382 -1287.867789  -387.371855  -411.427439
#
#         minimoD3     minimoD2     minimoD1  diagnostico
# 0    -211.146760  -742.225126  -588.261700         PNES
# 1   -1232.590217  -545.770228 -1453.482043         PNES
# 2    -840.277158 -1970.193913 -2763.513814         PNES
# 3    -452.175568 -1674.902817 -1170.970361         PNES
# 4    -743.498496  -824.346920 -1603.745333         PNES
# ..           ...          ...          ...          ...
# 139 -1882.455483 -1184.219351 -1840.831509           SE
# 140  -242.566129  -454.292935  -635.493115           SE
# 141  -593.263970  -437.224040  -731.165385           SE
# 142   -73.145770  -179.647883  -180.314317           SE
# 143  -249.403283  -631.160777 -1315.181206           SE
#
# [144 rows x 26 columns]

# %%
parametros = list(df.drop(columns=['diagnostico']).columns)
parametros
# Out:
# ['mediaA5',
#  'mediaD5',
#  'mediaD4',
#  'mediaD3',
#  'mediaD2',
#  'mediaD1',
#  'desvpadA5',
#  'desvpadD5',
#  'desvpadD4',
#  'desvpadD3',
#  'desvpadD2',
#  'desvpadD1',
#  'maximoA5',
#  'maximoD5',
#  'maximoD4',
#  'maximoD3',
#  'maximoD2',
#  'maximoD1',
#  'minimoA5',
#  'minimoD5',
#  'minimoD4',
#  'minimoD3',
#  'minimoD2',
#  'minimoD1']

# %%
sns.set_theme()
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",palette='plasma')

# %%
df.columns
# Out:
# Index(['id_paciente', 'mediaA5', 'mediaD5', 'mediaD4', 'mediaD3', 'mediaD2',
#        'mediaD1', 'desvpadA5', 'desvpadD5', 'desvpadD4', 'desvpadD3',
#        'desvpadD2', 'desvpadD1', 'maximoA5', 'maximoD5', 'maximoD4',
#        'maximoD3', 'maximoD2', 'maximoD1', 'minimoA5', 'minimoD5', 'minimoD4',
#        'minimoD3', 'minimoD2', 'minimoD1', 'diagnostico'],
#       dtype='object')

# %%
parametros=df.drop(columns=['id_paciente','diagnostico']).columns
parametros
# Out:
# Index(['mediaA5', 'mediaD5', 'mediaD4', 'mediaD3', 'mediaD2', 'mediaD1',
#        'desvpadA5', 'desvpadD5', 'desvpadD4', 'desvpadD3', 'desvpadD2',
#        'desvpadD1', 'maximoA5', 'maximoD5', 'maximoD4', 'maximoD3', 'maximoD2',
#        'maximoD1', 'minimoA5', 'minimoD5', 'minimoD4', 'minimoD3', 'minimoD2',
#        'minimoD1'],
#       dtype='object')

# %%
df_to_plot = pd.melt(frame=df[parametros].reset_index(),id_vars='index',var_name='column_name',value_name='value')
df_to_plot['diagnostico'] = np.where((df_to_plot['index']>=39), 'SE', 'PNES')
df_to_plot
# Out:
#       index column_name        value diagnostico
# 0         0     mediaA5     5.315671        PNES
# 1         1     mediaA5     2.007625        PNES
# 2         2     mediaA5     2.983112        PNES
# 3         3     mediaA5    -6.851432        PNES
# 4         4     mediaA5     5.212388        PNES
# ...     ...         ...          ...         ...
# 3451    139    minimoD1 -1840.831509          SE
# 3452    140    minimoD1  -635.493115          SE
# 3453    141    minimoD1  -731.165385          SE
# 3454    142    minimoD1  -180.314317          SE
# 3455    143    minimoD1 -1315.181206          SE
#
# [3456 rows x 4 columns]

# %%
df_to_plot.loc[df_to_plot['column_name'] == 'mediaA5']
# Out:
#      index column_name      value diagnostico
# 0        0     mediaA5   5.315671        PNES
# 1        1     mediaA5   2.007625        PNES
# 2        2     mediaA5   2.983112        PNES
# 3        3     mediaA5  -6.851432        PNES
# 4        4     mediaA5   5.212388        PNES
# ..     ...         ...        ...         ...
# 139    139     mediaA5   2.074674          SE
# 140    140     mediaA5   1.355568          SE
# 141    141     mediaA5   8.329793          SE
# 142    142     mediaA5   6.019530          SE
# 143    143     mediaA5 -13.643900          SE
#
# [144 rows x 4 columns]

# %%
# Create a visualization
sns.relplot(data=df_to_plot,x='index',y='value',hue='diagnostico',style='column_name',palette='plasma')

# %%
parametros
# Out:
# Index(['mediaA5', 'mediaD5', 'mediaD4', 'mediaD3', 'mediaD2', 'mediaD1',
#        'desvpadA5', 'desvpadD5', 'desvpadD4', 'desvpadD3', 'desvpadD2',
#        'desvpadD1', 'maximoA5', 'maximoD5', 'maximoD4', 'maximoD3', 'maximoD2',
#        'maximoD1', 'minimoA5', 'minimoD5', 'minimoD4', 'minimoD3', 'minimoD2',
#        'minimoD1'],
#       dtype='object')

# %%
filtro = [item for item in parametros if 'media' in item]
filtro
# Out:
# ['mediaA5', 'mediaD5', 'mediaD4', 'mediaD3', 'mediaD2', 'mediaD1']

# %%
# Create a visualization
sns.relplot(data=df_to_plot.loc[df_to_plot['column_name'].isin(filtro)],x='index',y='value',hue='diagnostico',style='column_name',palette='plasma')

# %%
df_to_plot[df_to_plot['column_name'].isin(filtro)].value_counts('diagnostico')
# Out:
# diagnostico
# PNES    630
# SE      234
# dtype: int64

# %%
# Create a visualization
sns.relplot(data=df_to_plot.loc[df_to_plot['column_name'].isin(['maximoA5'])],x='index',y='value',hue='diagnostico',style='column_name',palette='plasma')

# %%
tabela = sns.relplot(data=df)
